# %%
import pandas as pd
pd.set_option("display.width", 180)

# CSV 로드 (한글 데이터: encoding 명시 습관!)
df = pd.read_csv("sales_sample.csv", encoding="utf-8")
# Excel 로드도 한 줄: pd.read_excel("inventory_sample.xlsx", sheet_name="재고현황")

# 탐색 루틴: 로드하면 무조건 이 4가지부터
print(" === sales_sample csv 파일 내용 === ")
print(df.head())       # 앞 5행 미리보기
print(df.shape)        # (행 수, 열 수)
print(df.info())       # 열 이름, 타입, 결측 여부
print(df.describe())   # 숫자 열의 기초 통계
# Out:
#  === sales_sample csv 파일 내용 ===
#    order_id        date region product category  unit_price  quantity  total_price
# 0      1001  2025-01-01    홍대점    카페라떼       음료        5000         1         5000
# 1      1002  2025-01-01    신촌점    카푸치노       음료        5000         1         5000
# 2      1003  2025-01-01    신촌점    카페라떼       음료        5000         2        10000
# 3      1004  2025-01-01    강남점    카페라떼       음료        5000         1         5000
# 4      1005  2025-01-01    강남점   아메리카노       음료        4500         1         4500
# (504, 8)
# <class 'pandas.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     504 non-null    int64
#  1   date         504 non-null    str
#  2   region       504 non-null    str
#  3   product      504 non-null    str
#  4   category     504 non-null    str
#  5   unit_price   504 non-null    int64
#  6   quantity     504 non-null    int64
#  7   total_price  504 non-null    int64
# dtypes: int64(4), str(4)
# memory usage: 31.6 KB
# None
#           order_id   unit_price    quantity   total_price
# count   504.000000   504.000000  504.000000    504.000000
# mean   1252.500000  5194.444444    1.460317   7611.111111
# std     145.636534  1041.814105    0.641826   3776.898961
# min    1001.000000  3500.000000    1.000000   3500.000000
# 25%    1126.750000  4500.000000    1.000000   5000.000000
# 50%    1252.500000  5000.000000    1.000000   6000.000000
# 75%    1378.250000  6000.000000    2.000000  10000.000000
# max    1504.000000  7000.000000    3.000000  21000.000000

# %%
# 단일 조건: 음료 카테고리만
drinks = df[df["category"] == "음료"]
print(" === drinks 데이터프레임 === ")
print(drinks.head())

# 다중 조건: 음료이면서 수량 100 이상 — 각 조건을 괄호로, &(그리고) |(또는)
hot = df[(df["category"] == "음료") & (df["quantity"] >= 3)]
print(" === hot 데이터프레임 === ")
print(hot.head())
# Out:
#  === drinks 데이터프레임 ===
#    order_id        date region product category  unit_price  quantity  total_price
# 0      1001  2025-01-01    홍대점    카페라떼       음료        5000         1         5000
# 1      1002  2025-01-01    신촌점    카푸치노       음료        5000         1         5000
# 2      1003  2025-01-01    신촌점    카페라떼       음료        5000         2        10000
# 3      1004  2025-01-01    강남점    카페라떼       음료        5000         1         5000
# 4      1005  2025-01-01    강남점   아메리카노       음료        4500         1         4500
#  === hot 데이터프레임 ===
#      order_id        date region product category  unit_price  quantity  total_price
# 29       1030  2025-01-06    신촌점    카푸치노       음료        5000         3        15000
# 54       1055  2025-01-10    신촌점    카페라떼       음료        5000         3        15000
# 80       1081  2025-01-14    강남점   아메리카노       음료        4500         3        13500
# 168      1169  2025-01-31    강남점    카푸치노       음료        5000         3        15000
# 192      1193  2025-02-04    신촌점   바닐라라떼       음료        5500         3        16500

# %%
# 특정 값 목록에 포함: isin
target = df[df["product"].isin(["아메리카노", "카페라떼"])]
print(" === target 데이터프레임 === ")
print(target.head())
# Out:
#  === target 데이터프레임 ===
#     order_id        date region product category  unit_price  quantity  total_price
# 0       1001  2025-01-01    홍대점    카페라떼       음료        5000         1         5000
# 2       1003  2025-01-01    신촌점    카페라떼       음료        5000         2        10000
# 3       1004  2025-01-01    강남점    카페라떼       음료        5000         1         5000
# 4       1005  2025-01-01    강남점   아메리카노       음료        4500         1         4500
# 11      1012  2025-01-02    강남점    카페라떼       음료        5000         1         5000

# %%
# 매출액 = 단가 × 수량 : 열 전체에 대한 벡터 연산 (for문 불필요)
df["sales"] = df["unit_price"] * df["quantity"]
print(" === df 데이터프레임 (sales 추가)=== ")
print(df.head())
# Out:
#  === df 데이터프레임 (sales 추가)===
#    order_id        date region product category  unit_price  quantity  total_price  sales
# 0      1001  2025-01-01    홍대점    카페라떼       음료        5000         1         5000   5000
# 1      1002  2025-01-01    신촌점    카푸치노       음료        5000         1         5000   5000
# 2      1003  2025-01-01    신촌점    카페라떼       음료        5000         2        10000  10000
# 3      1004  2025-01-01    강남점    카페라떼       음료        5000         1         5000   5000
# 4      1005  2025-01-01    강남점   아메리카노       음료        4500         1         4500   4500

# %%
# 주문일자에서 '월' 추출 : 과제의 월별 집계에 필요
df["date"] = pd.to_datetime(df["date"])
df["month"] = df["date"].dt.month
print(" === df 데이터프레임 (month 추가)=== ")
print(df.head())
# Out:
#  === df 데이터프레임 (month 추가)===
#    order_id       date region product category  unit_price  quantity  total_price  sales  month
# 0      1001 2025-01-01    홍대점    카페라떼       음료        5000         1         5000   5000      1
# 1      1002 2025-01-01    신촌점    카푸치노       음료        5000         1         5000   5000      1
# 2      1003 2025-01-01    신촌점    카페라떼       음료        5000         2        10000  10000      1
# 3      1004 2025-01-01    강남점    카페라떼       음료        5000         1         5000   5000      1
# 4      1005 2025-01-01    강남점   아메리카노       음료        4500         1         4500   4500      1

# %%
top = df.sort_values("sales", ascending=False)          # 매출액 내림차순
print(" === top 데이터프레임 (매출액 내림차순)=== ")
print(top.head())
# Out:
#  === top 데이터프레임 (매출액 내림차순)===
#      order_id       date region product category  unit_price  quantity  total_price  sales  month
# 285      1286 2025-02-20    홍대점    샌드위치     베이커리        7000         3        21000  21000      2
# 344      1345 2025-03-01    신촌점    샌드위치     베이커리        7000         3        21000  21000      3
# 341      1342 2025-03-01    강남점    샌드위치     베이커리        7000         3        21000  21000      3
# 377      1378 2025-03-05    홍대점    샌드위치     베이커리        7000         3        21000  21000      3
# 310      1311 2025-02-23    신촌점   치즈케이크      디저트        6500         3        19500  19500      2

# %%
multi = df.sort_values(["category", "sales"], ascending=[True, False])
print(" === multi 데이터프레임 (category 오름차순, sales 내림차순)=== ")
print(multi.head())   # 가 – 나 - 다 순으로 정렬 이후 매출액 큰 값부터 정렬
# Out:
#  === multi 데이터프레임 (category 오름차순, sales 내림차순)===
#      order_id       date region product category  unit_price  quantity  total_price  sales  month
# 310      1311 2025-02-23    신촌점   치즈케이크      디저트        6500         3        19500  19500      2
# 346      1347 2025-03-01    홍대점   치즈케이크      디저트        6500         3        19500  19500      3
# 422      1423 2025-03-15    신촌점   치즈케이크      디저트        6500         3        19500  19500      3
# 40       1041 2025-01-08    강남점     크로플      디저트        6000         3        18000  18000      1
# 45       1046 2025-01-09    강남점     크로플      디저트        6000         3        18000  18000      1

# %%
by_cat = df.groupby("category")["sales"].sum()

# %%
by_cat = df.groupby("category")["sales"].sum()
print(" === category 별 매출액 합계 === ")
print(by_cat.head())
# Out:
#  === category 별 매출액 합계 ===
# category
# 디저트     1600500
# 베이커리     838000
# 음료      1397500
# Name: sales, dtype: int64

# %%
# 월별 × 카테고리별, 합계와 평균을 한 번에: agg
report = df.groupby(["month", "category"])["sales"].agg(
    총매출="sum", 평균매출="mean", 거래건수="count")
report = report.reset_index()   # 그룹 키를 일반 열로 되돌리기
print(report)
# Out:
#    month category     총매출         평균매출  거래건수
# 0      1      디저트  539500  7707.142857    70
# 1      1     베이커리  226000  7533.333333    30
# 2      1       음료  517000  7281.690141    71
# 3      2      디저트  533000  7724.637681    69
# 4      2     베이커리  339500  9700.000000    35
# 5      2       음료  460000  7076.923077    65
# 6      3      디저트  528000  7333.333333    72
# 7      3     베이커리  272500  8790.322581    31
# 8      3       음료  420500  6893.442623    61

# %%
# 월별 × 카테고리별, 합계와 평균을 한 번에: agg
report = df.groupby(["month", "category"])["sales"].agg(
    총매출="sum", 평균매출="mean", 거래건수="count")

print(report)
# Out:
#                    총매출         평균매출  거래건수
# month category
# 1     디저트       539500  7707.142857    70
#       베이커리      226000  7533.333333    30
#       음료        517000  7281.690141    71
# 2     디저트       533000  7724.637681    69
#       베이커리      339500  9700.000000    35
#       음료        460000  7076.923077    65
# 3     디저트       528000  7333.333333    72
#       베이커리      272500  8790.322581    31
#       음료        420500  6893.442623    61

# %%
# CSV로 저장: index=False(행 번호 제외), Excel에서 열 파일은 utf-8-sig
report.to_csv("report.csv", index=False, encoding="utf-8-sig")

# %%
# Excel로 저장: 시트 여러 개를 한 파일에
with pd.ExcelWriter("Monthly_Report.xlsx", engine="openpyxl") as writer:
    report.to_excel(writer, sheet_name="월별요약", index=False)
    by_cat.reset_index().to_excel(writer, sheet_name="카테고리별", index=False)

# %%
# %pip install openpyxl
# Out:
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.

# %%
df1 = pd.read_csv("RAW_DATA.csv", encoding="cp949")
print(df1.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   주문일자    500 non-null    str
#  1   상품명     500 non-null    str
#  2   카테고리    500 non-null    str
#  3   단가      500 non-null    str
#  4   수량      500 non-null    int64
# dtypes: int64(1), str(4)
# memory usage: 19.7 KB
# None
